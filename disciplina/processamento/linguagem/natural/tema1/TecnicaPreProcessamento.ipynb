# %%
#print("NLTK (sigla para Natural Language Toolkit) é uma biblioteca de código aberto \n para a linguagem de programação Python, \n amplamente utilizada para processamento de linguagem natural (PLN).")
#print("Diretório do corpus machado - /{$user}/nltk_data")
#print("O corpus machado está em outra pasta")
#import nltk as nl
#from nltk.corpus import PlaintextCorpusReader
#from nltk.corpus import machado importação padrão mas no meu caso não está funcionando



#nl.download()//download das obras de machado de assis

# %%
# Defina o caminho onde o corpus foi baixado
#caminho_corpus = '/home/waldemir/nltk_data/corpora/machado/'  # Altere para seu caminho

# Carregar o corpus manualmente
#machado = PlaintextCorpusReader(caminho_corpus, '.*')

#print(machado)
# Out:
# <PlaintextCorpusReader in '/home/waldemir/nltk_data/corpora/machado'>
