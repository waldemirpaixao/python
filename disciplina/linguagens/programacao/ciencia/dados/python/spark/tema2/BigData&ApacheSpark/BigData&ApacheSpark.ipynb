# %%
print("4vs do Big data: Volume, Velocidade, Variedade e Veracidade")
print("Apache Spark - é uma poderosa ferramenta de processamento de dados em tempo real, que permite a análise e" + 
      " \n transformação de grandes volumes de informações de" + 
      " \n forma rápida e eficiente. \n Sua arquitetura distribuída e reseiliente o " + 
      " \n torna idela para lidar com conjuntos de dados em constante crescimento")
