# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
print("Versão do MatPlotLib", mpl.__version__)
print("----------------------------------------------------------------------------------------")
print("Matplotlib é uma biblioteca de plotagem 2D que permite a criaçã de gráficos estáticos, animados e interativos em python.")
print("")
print("========================================================================================================================")
print("")
print("Plotagem simples")
plt.plot([1,2,3,4],[10,20,25,30])
plt.hist([1,2,1,3,3,3,4,4,4,4])
plt.ylabel('Eixo Y')
plt.xlabel('Eixo X')
plt.title('Meu primeiro gráfico')
plt.show()
# Out:
# Versão do MatPlotLib 3.10.7
# ----------------------------------------------------------------------------------------
# Matplotlib é uma biblioteca de plotagem 2D que permite a criaçã de gráficos estáticos, animados e interativos em python.
#
# ...
#
# Plotagem simples
