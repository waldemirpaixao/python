# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
print("Versão do MatPlotLib", mpl.__version__)
print("----------------------------------------------------------------------------------------")
print("Scikit-learn é uma biblioteca de machine learning (aprendizado de máquina) em pthon, \n"+ 
      "que oferece ferramentas simples e eficinetes para anlálise e mineração de dados. \n Ela é construída sobre outras bibliotecas populares do Pythom como: NumPy, SciPy e Matplotlib. ")
print("Aprendizado Supervisionado")
print("O modelo é treinado usando um conjunto de dados rotulado. Isso significa" + 
      "\n que cada exemplo de treinamento é composto por uma entyrda e a saída" +
      "\n desejada (rótulo). O objetivo do modelo é aprender a mapear entradas" + 
      "\n para saídas corretas, de modo a fazer previsõe precisas para novos dados não vistos")
print("Aprendizado Não Supervisionado")
print("O modelo é treinado usando um conjunto de dados não rotulado. \n" + 
      "O objetivo do modelo é identificar padrões, estruturas ou agrupamentos nos dados sem orientação explícita.")
print("")
print("========================================================================================================================")
print("")
# Out:
# Versão do MatPlotLib 3.10.7
# ----------------------------------------------------------------------------------------
# Scikit-learn é uma biblioteca de machine learning (aprendizado de máquina) em pthon,
# que oferece ferramentas simples e eficinetes para anlálise e mineração de dados.
#  Ela é construída sobre outras bibliotecas populares do Pythom como: NumPy, SciPy e Matplotlib.
# Aprendizado Supervisionado
# O modelo é treinado usando um conjunto de dados rotulado. Isso significa
#  que cada exemplo de treinamento é composto por uma entyrda e a saída
#  desejada (rótulo). O objetivo do modelo é aprender a mapear entradas
#  para saídas corretas, de modo a fazer previsõe precisas para novos dados não vistos
# Aprendizado Não Supervisionado
# O modelo é treinado usando um conjunto de dados não rotulado.
# O objetivo do modelo é identificar padrões, estruturas ou agrupamentos nos dados sem orientação explícita.
#
# ...
